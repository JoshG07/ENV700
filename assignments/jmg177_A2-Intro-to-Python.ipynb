# %% [markdown]
# ```
# ENV 700: Environmental Data Exploration - Python
# Fall 2026 -- Instructor: John Fay
# ```
#
# # Assignment 1 - Python Fundamentals Assessment
#
# **Name:** Josh Goozman
#
# **Instructions:**
# - Complete all questions in this notebook.
# - Use both Markdown and Code cells where indicated.
# - Run all code cells before submission.
# - Save the completed notebook and submit it.

# %% [markdown]
# # Part 1: Jupyter Notebooks and Markdown (10 points)
#
# Create a new Markdown cell below this section and:
# 1. Add a level-1 heading.
# 2. Add a level-2 heading.
# 3. Create a bulleted list with three items.
# 4. Write one sentence describing what a Jupyter Notebook is.

# %% [markdown]
# # My Level-1 Heading
#
# ## My Level-2 Heading
#
# Bulleted List:
# - Apples
# - Bananas
# - Oranges
#
# A Jupyter Notebook is a type of document that can contain both code cells for running Python and markdown cells for descriptions, explanations, comments, etc.

# %% [markdown]
# # Part 2: Variables and Data Types (15 points)

# %% [markdown]
# In the code cell below:
#
# 1. Create a variable named `temperature` and assign it a numeric value.
# 2. Create a variable named `city` containing a string.
# 3. Create a variable named `is_raining` containing a Boolean value.
# 4. Print each variable.
# 5. Use `type()` to display the data type of each variable.

# %%
# Write your solution here
temperature = 12.4
city = "Durham"
is_raining = False

print(temperature, type(temperature))
print(city, type(city))
print(is_raining, type (is_raining))
# Out:
# 12.4 <class 'float'>
# Durham <class 'str'>
# False <class 'bool'>

# %% [markdown]
# # Part 3: Collections (25 points)

# %% [markdown]
# Complete the following tasks.
#
# ### A. Tuple
# - Create a tuple containing the names of four seasons.
#
# ### B. List
# - Create a list containing five environmental measurements between -50 and 50.
# - Add one additional value to the list.
# - Print the third item in the list.
#
# ### C. Dictionary
# - Create a dictionary describing a weather station with keys:
#   - `station`
#   - `latitude`
#   - `longitude`
# - Print the latitude.
#
# ### D. Set
# - Create a set containing several land-cover classes.
# - Demonstrate that duplicate values are removed.

# %%
# Part A
seasons = ("Spring", "Summer", "Fall", "Winter")
print(seasons)
print(type(seasons))
# Out:
# ('Spring', 'Summer', 'Fall', 'Winter')
# <class 'tuple'>

# %%
#Part B
measures = [2.5, 6.0, -27.4, 48.2, 26.9]
print(type(measures))
measures.append(-3.7)
print(measures)
print(measures[2])
# Out:
# <class 'list'>
# [2.5, 6.0, -27.4, 48.2, 26.9, -3.7]
# -27.4

# %%
#Part C
weather_station = {
    "station" : "2C",
    "latitude" : 34.65,
    "longitude" : -12.74
}
print(type(weather_station))

print(weather_station["latitude"])
# Out:
# <class 'dict'>
# 34.65

# %%
#Part D
land_cover_classes = {"forest", "lake", "wetland", "forest", "meadow", "lake", "forest"}
print(type(land_cover_classes))

print(land_cover_classes)
# duplicate values in set are not shown in output
# Out:
# <class 'set'>
# {'meadow', 'forest', 'lake', 'wetland'}

# %% [markdown]
# # Part 4: Conditional Statements (15 points)

# %% [markdown]
# Write code that:
#
# 1. Creates a variable called `air_quality_index`, assigning a value between 0 and 250.
# 2. Uses an `if`, `elif`, and `else` statement to classify the value as:
#    - Good (< 50)
#    - Moderate (50–100)
#    - Poor (> 100)
# 3. Prints the classification.

# %%
# Write your solution here
air_quality_index = 50

if air_quality_index < 50:
    print("Good")
elif air_quality_index <= 100:
    print("Moderate")
else:
    print("Poor")
# Out:
# Moderate

# %% [markdown]
# # Part 5: Loops (20 points)

# %% [markdown]
# ### A. For Loop
# - Create a list of five years.
# - Use a `for` loop to print each year.
#
# ### B. While Loop
# - Create a counter starting at 1.
# - Use a `while` loop to print numbers from 1 to 5.
#
# ### C. Challenge
# - Use a loop to calculate the sum of the numbers from 1 to 10.
# - Print the result.

# %%
# Part A
years = [2000, 2005, 2010, 2015, 2020]

for i in years:
    print(i)
# Out:
# 2000
# 2005
# 2010
# 2015
# 2020

# %%
#Part B
counter = 1

while counter <= 5:
    print(counter)
    counter += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Part C
number = 1
total = 0

while number <= 10:
    total += number
    number += 1

print(total)
# Out:
# 55

# %% [markdown]
# # Part 6: Functions (15 points)

# %% [markdown]
# ### A. Function with One Input
# - Create a function called `circle_area()`.
# - The function should accept a value representing the radius of a circle and return the area of a circle with that radus (`area = 2πr`).
# - Challenge: Use the math package to get the value of π. (Otherwise use `3.14`.)
#
# ### B. Function with Two Inputs
# - Create a function called `rectangle_area()`.
# - The function should accept length and width and return area.
#
# ### C. Function with Two Outputs
# - Create a function called `min_max_values()`.
# - The function should accept a list of numbers.
# - Return both the minimum and maximum values.
#
# Demonstrate each function with example inputs.

# %%
# Part A
import math

# Note: The area of a circle is πr^2, not 2πr, so that is what I used

def circle_area (radius):
    area = math.pi*radius*radius
    return area

print(circle_area(1))
print(circle_area(2))
print(circle_area(5))
# Out:
# 3.141592653589793
# 12.566370614359172
# 78.53981633974483

# %%
#Part B
def rectangle_area(length, width):
    area = length * width
    return area

print(rectangle_area(1, 1))
print(rectangle_area(2, 3))
print(rectangle_area(6, 2))
# Out:
# 1
# 6
# 12

# %%
#Part C
def min_max_values (list):
    return min(list), max(list)

numbers = [2.8, 5.16, 4, -20, 4.6, 13.3]
print(min_max_values(numbers))

more_numbers = [87, 145, 10, 54, 203, 4, 28]
print(min_max_values(more_numbers))
# Out:
# (-20, 13.3)
# (4, 203)

# %% [markdown]
# # Reflection (Optional Bonus: 2 points)
#
# In a Markdown cell, briefly describe:
# - Which topic was easiest for you?
# - Which topic was most challenging?
# - One thing you would like to learn next.

# %% [markdown]
# For me, the easiest topic was learning to create variables and collections. I have experience in R, which has very similar types of those things. I am used to defining them and using them within other code like functions and if-statements.
#
# The most challenging thing for me was remembering all of the Python-specific syntax. Although knowing R helps conceptually, there are still major differences in the way you actually type code. I am now getting used to using colons in if-statements and functions, as well as hard brackets and curly brackets to define different types of collections, which aren't often utilized in R.
#
# Next, I would like to explore the graphing software in Python, since data visualization plays such an important role in drawing conclusions. Graphs are also super useful for communicating findings to others, both scientists and the public. I'm curious how they compare to the graphs I have made previously in R using ggplot.
